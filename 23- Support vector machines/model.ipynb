# %% [markdown]
# svm

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
## lets create syntehtic dataset

from sklearn.datasets import make_classification

# %%
X,y=make_classification(n_samples=1000,n_features=2,n_classes=2,n_clusters_per_class=1,n_redundant=0)

# %%
X
# Out:
# array([[ 2.85843701,  1.1656661 ],
#        [ 1.11973397,  1.07391256],
#        [-1.45138316,  0.90484208],
#        ...,
#        [ 0.67087347,  1.29616067],
#        [-1.07683159,  1.06638003],
#        [ 1.08966885,  0.95432562]], shape=(1000, 2))

# %%
pd.DataFrame(X)[0]
# Out:
# 0      2.858437
# 1      1.119734
# 2     -1.451383
# 3      0.823500
# 4     -1.035899
#          ...
# 995   -2.168349
# 996   -1.382264
# 997    0.670873
# 998   -1.076832
# 999    1.089669
# Name: 0, Length: 1000, dtype: float64

# %%
sns.scatterplot(
    x=pd.DataFrame(X)[0],
    y=pd.DataFrame(X)[1],
    hue=y
)
# Out:
# <Axes: xlabel='0', ylabel='1'>

# %%
from sklearn.model_selection import train_test_split

X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.25,random_state=10)

# %%
from sklearn.svm import SVC

# %%
svc=SVC(kernel='linear')

# %%
svc.fit(X_train,y_train)
# Out:
# SVC(kernel='linear')

# %%
## prediction

y_pred=svc.predict(X_test)

# %%
from sklearn.metrics import classification_report,confusion_matrix

# %%
print(classification_report(y_test,y_pred))
print(confusion_matrix(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.92      0.89      0.90       134
#            1       0.88      0.91      0.89       116
#
#     accuracy                           0.90       250
#    macro avg       0.90      0.90      0.90       250
# weighted avg       0.90      0.90      0.90       250
#
# [[119  15]
#  [ 11 105]]
