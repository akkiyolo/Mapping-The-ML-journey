# %%
from sklearn.datasets import make_classification

import numpy as np
X,y=make_classification(n_samples=100,n_features=2,n_informative=1,n_redundant=0,n_classes=2,n_clusters_per_class=1,random_state=41,hypercube=False,class_sep=10)

# %%
# !pip install matplotlib
# Out:
# Collecting matplotlib
#   Using cached matplotlib-3.10.9-cp312-cp312-win_amd64.whl.metadata (52 kB)
# Requirement already satisfied: contourpy>=1.0.1 in d:\cse everything\ml with python\venv\lib\site-packages (from matplotlib) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in d:\cse everything\ml with python\venv\lib\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in d:\cse everything\ml with python\venv\lib\site-packages (from matplotlib) (4.59.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in d:\cse everything\ml with python\venv\lib\site-packages (from matplotlib) (1.4.8)
# Requirement already satisfied: numpy>=1.23 in d:\cse everything\ml with python\venv\lib\site-packages (from matplotlib) (2.4.4)
# Requirement already satisfied: packaging>=20.0 in d:\cse everything\ml with python\venv\lib\site-packages (from matplotlib) (25.0)
# Requirement already satisfied: pillow>=8 in d:\cse everything\ml with python\venv\lib\site-packages (from matplotlib) (11.3.0)
# Requirement already satisfied: pyparsing>=3 in d:\cse everything\ml with python\venv\lib\site-packages (from matplotlib) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in d:\cse everything\ml with python\venv\lib\site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in d:\cse everything\ml with python\venv\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
# Using cached matplotlib-3.10.9-cp312-cp312-win_amd64.whl (8.2 MB)
# Installing collected packages: matplotlib
# WARNING: Ignoring invalid distribution ~atplotlib (D:\CSE EVERYTHING\ML with Python\venv\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~atplotlib (D:\CSE EVERYTHING\ML with Python\venv\Lib\site-packages)
# ERROR: Could not install packages due to an OSError: [WinError 5] Access is denied: 'D:\\CSE EVERYTHING\\ML with Python\\venv\\Lib\\site-packages\\matplotlib\\_c_internal_utils.cp312-win_amd64.pyd'
# Check the permissions.
#
#
# [notice] A new release of pip is available: 25.1.1 -> 26.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# !python -m pip install --upgrade pip
# Out:
# Requirement already satisfied: pip in d:\cse everything\ml with python\venv\lib\site-packages (25.1.1)
# Collecting pip
#   Using cached pip-26.1.1-py3-none-any.whl.metadata (4.6 kB)
# Using cached pip-26.1.1-py3-none-any.whl (1.8 MB)
# Installing collected packages: pip
#   Attempting uninstall: pip
#     Found existing installation: pip 25.1.1
#     Uninstalling pip-25.1.1:
#       Successfully uninstalled pip-25.1.1
# Successfully installed pip-26.1.1
# WARNING: Ignoring invalid distribution ~atplotlib (d:\CSE EVERYTHING\ML with Python\venv\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~atplotlib (d:\CSE EVERYTHING\ML with Python\venv\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~atplotlib (d:\CSE EVERYTHING\ML with Python\venv\Lib\site-packages)

# %%
import matplotlib.pyplot as plt
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 import matplotlib.pyplot as plt
#
# File d:\CSE EVERYTHING\ML with Python\venv\Lib\site-packages\matplotlib\__init__.py:161
#     157 from packaging.version import parse as parse_version
#     159 # cbook must import matplotlib only within function
#     160 # definitions, so it is safe to import from it here.
# --> 161 from . import _api, _version, cbook, _docstring, rcsetup
#     162 from matplotlib._api import MatplotlibDeprecationWarning
#     163 from matplotlib.rcsetup import cycler  # noqa: F401
#
# File d:\CSE EVERYTHING\ML with Python\venv\Lib\site-packages\matplotlib\rcsetup.py:26
#      23 import numpy as np
#      25 from matplotlib import _api, cbook
# ---> 26 from matplotlib.backends import BackendFilter, backend_registry
#      27 from matplotlib.cbook import ls_mapper
#      28 from matplotlib.colors import Colormap, is_color_like
#
# File d:\CSE EVERYTHING\ML with Python\venv\Lib\site-packages\matplotlib\backends\__init__.py:1
# ----> 1 from .registry import BackendFilter, backend_registry  # noqa: F401
#       3 # NOTE: plt.switch_backend() (called at import time) will add a "backend"
#       4 # attribute here for backcompat.
#       5 _QT_FORCE_QT5_BINDING = False
#
# ModuleNotFoundError: No module named 'matplotlib.backends.registry'
