# %% [markdown]
# ##### Streamlit
#
# It is an open source app framework for machine learning and data science projects.It allows you creating beautiful apps for your machine learning and data science projects using simple python scripts.
